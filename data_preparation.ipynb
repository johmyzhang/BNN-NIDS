# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('data/Friday-WorkingHours-Morning.pcap_ISCX.csv')
df2 = pd.read_csv('data/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv')
df3 = pd.read_csv('data/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')
df4 = pd.read_csv('data/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv')
df5 = pd.read_csv('data/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv')
df6 = pd.read_csv('data/Tuesday-WorkingHours.pcap_ISCX.csv')
df7 = pd.read_csv('data/Wednesday-WorkingHours.pcap_ISCX.csv')
df8 = pd.read_csv('data/Monday-WorkingHours.pcap_ISCX.csv')
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8], ignore_index=True)

# %%
selected_headers = [
    ' Flow Duration',
    'Total Length of Fwd Packets',  # Total Len F.Packets
    # ' Total Length of Bwd Packets',  # Total Len B.Packets
    # ' Fwd Packet Length Min',  # F.Packet Len Min
    # ' Fwd Packet Length Mean',  # F.Packet Len Mean
    ' Bwd Packet Length Min',  # B.Packet Len Min
    ' Bwd Packet Length Std',  # B.Packet Len Std
    # ' Flow IAT Mean',
    # ' Flow IAT Std',
    # ' Flow IAT Min',
    # ' Fwd IAT Mean',  # FIAT Mean
    # ' Fwd IAT Min',  # FIAT Min / Fwd IAT Min
    ' Bwd IAT Mean',
    # ' Bwd IAT Min',
    'Fwd PSH Flags',  # FPSH Flags
    ' PSH Flag Count',
    # ' ACK Flag Count',
    ' SYN Flag Count',
    'Fwd Packets/s',  # F.Packets/s
    ' Bwd Packets/s',  # B.Packets/s
    ' Subflow Fwd Bytes',  # Subflow F.Bytes
    ' Subflow Bwd Bytes',  # Subflow B.Bytes
    'Init_Win_bytes_forward',  # Init Win F.Bytes
    ' Init_Win_bytes_backward',  # Init Win B.Bytes
    'Active Mean',
    ' Active Min',
    ' Label'  # Assuming you need the label column for classification
]

# %%
df = df[selected_headers]
df['Fwd Packets/s'] = df['Fwd Packets/s'].astype(int)
df[' Bwd Packets/s'] = df[' Bwd Packets/s'].astype(int)
df[' Bwd IAT Mean'] = df[' Bwd IAT Mean'].astype(int)
# df[' Fwd IAT Mean'] = df[' Fwd IAT Mean'].astype(int)
# df[' Flow IAT Std'] = df[' Flow IAT Std'].astype(int)
# df[' Flow IAT Mean'] = df[' Flow IAT Mean'].astype(int)
df['Active Mean'] = df['Active Mean'].astype(int)
df[' Bwd Packet Length Std'] = df[' Bwd Packet Length Std'].astype(int)
# df[' Fwd Packet Length Mean'] = df[' Fwd Packet Length Mean'].astype(int)

df
# Out:
#           Flow Duration  Total Length of Fwd Packets   Bwd Packet Length Min  \
# 0             112740690                         6448                      72
# 1             112740560                         6448                     316
# 2             113757377                            0                       0
# 3                100126                          616                       0
# 4                 54760                            0                       0
# ...                 ...                          ...                     ...
# 2830738           18738                            6                       6
# 2830739           60797                           80                      78
# 2830740             154                           64                      48
# 2830741             155                           80                      72
# 2830742              18                            0                       0
#
#           Bwd Packet Length Std   Bwd IAT Mean  Fwd PSH Flags  \
# 0                             0        7516023              1
# 1                             0        7516016              1
# 2                             0              0              0
# 3                             0              0              0
# 4                             0              0              0
# ...                         ...            ...            ...
# 2830738                       0              0              0
# 2830739                       0              3              0
# 2830740                       0             47              0
# 2830741                       0              4              0
# 2830742                       0              0              0
#
#           PSH Flag Count   SYN Flag Count  Fwd Packets/s   Bwd Packets/s  \
# 0                      0                1              0               0
# 1                      0                1              0               0
# 2                      0                0              4               0
# 3                      0                0            219               0
# 4                      0                0             73               0
# ...                  ...              ...            ...             ...
# 2830738                0                0             53              53
# 2830739                0                0             32              32
# 2830740                0                0          12987           12987
# 2830741                0                0          12903           12903
# 2830742                0                0          55555           55555
#
#           Subflow Fwd Bytes   Subflow Bwd Bytes  Init_Win_bytes_forward  \
# 0                      6448                1152                     377
# 1                      6448                5056                     955
# 2                         0                   0                      -1
# 3                       616                   0                      -1
# 4                         0                   0                      -1
# ...                     ...                 ...                     ...
# 2830738                   6                   6                       0
# 2830739                  80                 156                      -1
# 2830740                  64                  96                      -1
# 2830741                  80                 144                      -1
# 2830742                   0                   0                     357
#
#           Init_Win_bytes_backward  Active Mean   Active Min   Label
# 0                            2079          359          343  BENIGN
# 1                            2079          320          285  BENIGN
# 2                              -1      9361828           19  BENIGN
# 3                              -1            0            0  BENIGN
# 4                              -1            0            0  BENIGN
# ...                           ...          ...          ...     ...
# 2830738                       294            0            0  BENIGN
# 2830739                        -1            0            0  BENIGN
# 2830740                        -1            0            0  BENIGN
# 2830741                        -1            0            0  BENIGN
# 2830742                     65535            0            0  BENIGN
#
# [2830743 rows x 17 columns]

# %%
df[' Label'].value_counts()
# Out:
#  Label
# BENIGN                        2273097
# DoS Hulk                       231073
# PortScan                       158930
# DDoS                           128027
# DoS GoldenEye                   10293
# FTP-Patator                      7938
# SSH-Patator                      5897
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Bot                              1966
# Web Attack � Brute Force         1507
# Web Attack � XSS                  652
# Infiltration                       36
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import QuantileTransformer

# Transform all features into the scale of [0,1]
numeric_features = df.dtypes[df.dtypes != 'object'].index
scaler = QuantileTransformer()
df[numeric_features] = scaler.fit_transform(df[numeric_features])

# %%
df.describe()
# Out:
#         Flow Duration  Total Length of Fwd Packets   Bwd Packet Length Min  \
# count    2.830743e+06                 2.830743e+06            2.830743e+06
# mean     4.973213e-01                 4.843231e-01            3.727841e-01
# std      2.871944e-01                 3.067720e-01            3.912783e-01
# min      0.000000e+00                 0.000000e+00            0.000000e+00
# 25%      2.487487e-01                 2.697698e-01            0.000000e+00
# 50%      4.956545e-01                 4.969970e-01            0.000000e+00
# 75%      7.468703e-01                 7.447447e-01            7.557558e-01
# max      1.000000e+00                 1.000000e+00            1.000000e+00
#
#         Bwd Packet Length Std   Bwd IAT Mean  Fwd PSH Flags   PSH Flag Count  \
# count            2.830743e+06   2.830743e+06   2.830743e+06     2.830743e+06
# mean             2.436630e-01   4.004944e-01   4.644646e-02     2.980705e-01
# std              3.895156e-01   3.757930e-01   2.104500e-01     4.574107e-01
# min              0.000000e+00   0.000000e+00   0.000000e+00     0.000000e+00
# 25%              0.000000e+00   0.000000e+00   0.000000e+00     0.000000e+00
# 50%              0.000000e+00   5.110110e-01   0.000000e+00     0.000000e+00
# 75%              7.472472e-01   7.456376e-01   0.000000e+00     1.000000e+00
# max              1.000000e+00   1.000000e+00   1.000000e+00     1.000000e+00
#
#         SYN Flag Count  Fwd Packets/s   Bwd Packets/s   Subflow Fwd Bytes  \
# count     2.830743e+06   2.830743e+06    2.830743e+06        2.830743e+06
# mean      4.644646e-02   4.790304e-01    4.373949e-01        4.843231e-01
# std       2.104500e-01   3.190250e-01    3.609176e-01        3.067720e-01
# min       0.000000e+00   0.000000e+00    0.000000e+00        0.000000e+00
# 25%       0.000000e+00   2.392392e-01    0.000000e+00        2.697698e-01
# 50%       0.000000e+00   5.050050e-01    5.100100e-01        4.969970e-01
# 75%       0.000000e+00   7.527528e-01    7.543435e-01        7.447447e-01
# max       1.000000e+00   1.000000e+00    1.000000e+00        1.000000e+00
#
#         Subflow Bwd Bytes  Init_Win_bytes_forward   Init_Win_bytes_backward  \
# count        2.830743e+06            2.830743e+06              2.830743e+06
# mean         4.685642e-01            4.383039e-01              3.700159e-01
# std          3.286443e-01            3.569636e-01              3.893509e-01
# min          0.000000e+00            0.000000e+00              0.000000e+00
# 25%          0.000000e+00            0.000000e+00              0.000000e+00
# 50%          5.018291e-01            4.894895e-01              0.000000e+00
# 75%          7.472472e-01            7.787788e-01              7.657658e-01
# max          1.000000e+00            1.000000e+00              1.000000e+00
#
#         Active Mean    Active Min
# count  2.830743e+06  2.830743e+06
# mean   1.772281e-01  1.774629e-01
# std    3.583102e-01  3.587815e-01
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00
# max    1.000000e+00  1.000000e+00

# %%
# Multiply the feature values by 255 to transform them into the scale of [0,255]
df[numeric_features] = df[numeric_features].apply(
    lambda x: (x*255).astype(int))

# %%
df.describe()
mapping = {'DoS Hulk': 1, 'BENIGN': 0, 'DoS GoldenEye': 1, 'DoS slowloris': 1, 'DoS Slowhttptest': 1, 'Heartbleed': 1, 'DDoS': 1, 'PortScan': 1, 'FTP-Patator':1, 'SSH-Patator':1, 'Bot': 1, 'Web Attack � Brute Force': 1, 'Web Attack � XSS': 1, 'Infiltration': 1, 'Web Attack � Sql Injection': 1}
df[' Label'] = df[' Label'].replace(mapping)
# Out:
# /var/folders/wt/j9_cbksd2kz0p3yp2hgggs3c0000gn/T/ipykernel_5942/31415763.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[' Label'] = df[' Label'].replace(mapping)

# %%
df
# Out:
#           Flow Duration  Total Length of Fwd Packets   Bwd Packet Length Min  \
# 0                   244                          250                     189
# 1                   244                          250                     253
# 2                   244                            0                       0
# 3                   158                          219                       0
# 4                   141                            0                       0
# ...                 ...                          ...                     ...
# 2830738             108                           56                     148
# 2830739             145                          156                     193
# 2830740              63                          130                     170
# 2830741              63                          156                     189
# 2830742              20                            0                       0
#
#           Bwd Packet Length Std   Bwd IAT Mean  Fwd PSH Flags  \
# 0                             0            240            255
# 1                             0            240            255
# 2                             0              0              0
# 3                             0              0              0
# 4                             0              0              0
# ...                         ...            ...            ...
# 2830738                       0              0              0
# 2830739                       0            130              0
# 2830740                       0            156              0
# 2830741                       0            147              0
# 2830742                       0              0              0
#
#           PSH Flag Count   SYN Flag Count  Fwd Packets/s   Bwd Packets/s  \
# 0                      0              255              0               0
# 1                      0              255              0               0
# 2                      0                0             73               0
# 3                      0                0            148               0
# 4                      0                0            136               0
# ...                  ...              ...            ...             ...
# 2830738                0                0            126             162
# 2830739                0                0            109             145
# 2830740                0                0            196             221
# 2830741                0                0            196             221
# 2830742                0                0            233             251
#
#           Subflow Fwd Bytes   Subflow Bwd Bytes  Init_Win_bytes_forward  \
# 0                       250                 198                     159
# 1                       250                 216                     164
# 2                         0                   0                       0
# 3                       219                   0                       0
# 4                         0                   0                       0
# ...                     ...                 ...                     ...
# 2830738                  56                  77                      94
# 2830739                 156                 139                       0
# 2830740                 130                 111                       0
# 2830741                 156                 135                       0
# 2830742                   0                   0                     157
#
#           Init_Win_bytes_backward  Active Mean   Active Min   Label
# 0                             237          206          206       0
# 1                             237          206          206       0
# 2                               0          254          205       0
# 3                               0            0            0       0
# 4                               0            0            0       0
# ...                           ...          ...          ...     ...
# 2830738                       216            0            0       0
# 2830739                         0            0            0       0
# 2830740                         0            0            0       0
# 2830741                         0            0            0       0
# 2830742                       255            0            0       0
#
# [2830743 rows x 17 columns]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2, random_state=42)

train.to_csv('data/train_merged.csv', index=False, header=False)
test.to_csv('data/test_merged.csv', index=False, header=False)
